# %%
from game_v2 import score_game, random_predict

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 125 попыток
# 125

# %%
a = 4
b = a

# %%
c = a - b

# %% [markdown]
# Then smth will be started
